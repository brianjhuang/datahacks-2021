# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
observations = pd.read_csv("data/observations_train.csv")
series = pd.read_csv("data/series.csv")
series.head()
# Out:
#         series_id                                               name  \
# 0          AAA10Y  Moodys Seasoned Aaa Corporate Bond Yield Relat...
# 1        ASEANTOT        Import Price Index: ASEAN - All commodities
# 2          BAA10Y  Moodys Seasoned Baa Corporate Bond Yield Relat...
# 3    BUSAPPWNSAUS        Business Applications for the United States
# 4  BUSAPPWNSAUSYY        Business Applications for the United States
#
#                  frequency                         units  \
# 0                    Daily                       Percent
# 1                  Monthly            Index Dec 2003=100
# 2                    Daily                       Percent
# 3  Weekly, Ending Saturday                        Number
# 4  Weekly, Ending Saturday  Percent Change from Year Ago
#
#        seasonal_adjustment                                        Description
# 0  Not Seasonally Adjusted  Series is calculated as the spread between Moo...
# 1  Not Seasonally Adjusted  For more information, please see the Import/Ex...
# 2  Not Seasonally Adjusted  Series is calculated as the spread between Moo...
# 3  Not Seasonally Adjusted  Business Applications (BA): The core business ...
# 4  Not Seasonally Adjusted  Business Applications (BA): The core business ...

# %%
series.groupby("seasonal_adjustment").count()
# Out:
#                          series_id  name  frequency  units  Description
# seasonal_adjustment
# Not Seasonally Adjusted         52    52         52     52           36
# Seasonally Adjusted             19    19         19     19            4

# %%
series.query("""seasonal_adjustment == 'Seasonally Adjusted'  """)
# Out:
#             series_id                                               name  \
# 24        GVIPT50002S  Gross Value Weighted Industrial Production: Fi...
# 25        GVIPT50030S  Gross Value Weighted Industrial Production: Fi...
# 26        GVIPT51000S  Gross Value Weighted Industrial Production: Co...
# 27        GVIPT51100S  Gross Value Weighted Industrial Production: Du...
# 28        GVIPT51110S  Gross Value Weighted Industrial Production: Au...
# 29        GVIPT51120S  Gross Value Weighted Industrial Production: Ot...
# 30        GVIPT51200S  Gross Value Weighted Industrial Production: No...
# 31        GVIPT52000S  Gross Value Weighted Industrial Production: Eq...
# 32        GVIPT52100S  Gross Value Weighted Industrial Production: Bu...
# 33        GVIPT521A3S  Gross Value Weighted Industrial Production: Bu...
# 34        GVIPT52300S  Gross Value Weighted Industrial Production: De...
# 35        GVIPT54000S  Gross Value Weighted Industrial Production: No...
# 36        GVIPT54100S  Gross Value Weighted Industrial Production: Co...
# 37        GVIPT54200S  Gross Value Weighted Industrial Production: Bu...
# 38        GVIPT54220S  Gross Value Weighted Industrial Production: Co...
# 42  MEDCPIM158SFRBCLE                        Median Consumer Price Index
# 60  SFTPAGRM158SFRBSF                           San Francisco Tech Pulse
# 68           TSIFRGHT              Freight Transportation Services Index
# 69             UNRATE                                  Unemployment Rate
#
#    frequency                          units  seasonal_adjustment  \
# 24   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 25   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 26   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 27   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 28   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 29   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 30   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 31   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 32   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 33   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 34   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 35   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 36   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 37   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 38   Monthly    Billions of 2012 US Dollars  Seasonally Adjusted
# 42   Monthly  Percent Change at Annual Rate  Seasonally Adjusted
# 60   Monthly  Percent Change at Annual Rate  Seasonally Adjusted
# 68   Monthly      Chain-type Index 2000=100  Seasonally Adjusted
# 69   Monthly                        Percent  Seasonally Adjusted
#
#                                           Description
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 42  Median Consumer Price Index (CPI) is a measure...
# 60  The Tech Pulse release has been discontinued a...
# 68  The freight transportation services index cons...
# 69  The unemployment rate represents the number of...

# %%
observations.head()
# Out:
#   series_id                         date  value
# 0    AAA10Y  2000-01-03 00:00:00.0000000   1.17
# 1    AAA10Y  2000-01-04 00:00:00.0000000   1.20
# 2    AAA10Y  2000-01-05 00:00:00.0000000   1.16
# 3    AAA10Y  2000-01-06 00:00:00.0000000   1.15
# 4    AAA10Y  2000-01-07 00:00:00.0000000   1.17

# %%
observations['date'] = pd.to_datetime(observations['date'])
obs = observations.pivot_table(values="value", index="date", columns="series_id")

# %%
SP500 = obs['SP500']
SP500.dropna(inplace=True)
SP500.head()
# Out:
# date
# 2011-02-14    1332.32
# 2011-02-15    1328.01
# 2011-02-16    1336.32
# 2011-02-17    1340.43
# 2011-02-18    1343.01
# Name: SP500, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 9))
obs.drop(columns=["BUSAPPWNSAUS"]).plot(ax=ax)
ax.legend("off")
# ax.set_ylim([0, 10_000])

# %%
obs.max()
# Out:
# series_id
# AAA10Y                3.000
# ASEANTOT            106.200
# BAA10Y                6.160
# BUSAPPWNSAUS      85450.000
# BUSAPPWNSAUSYY      687.950
#                     ...
# TLAACBW027NBOG    16841.372
# TLBACBW027NBOG    14989.244
# TSIFRGHT            133.600
# UNRATE               10.000
# WLEMUINDXD         1811.330
# Length: 68, dtype: float64

# %%
series.query("""series_id == 'BUSAPPWNSAUS'""")
obs['BUSAPPWNSAUS'].dropna().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Normalize Values

# %%
normalize = lambda col: (col-col.mean())/col.std()

normed_obs = obs.apply(normalize, axis=0)

# %%
fig, ax = plt.subplots(figsize=(16, 9))
normed_obs.plot(ax=ax)
ax.legend("off")

# %%
normed_obs.corr()['SP500']
# Out:
# series_id
# AAA10Y           -0.702341
# ASEANTOT         -0.845046
# BAA10Y           -0.640168
# BUSAPPWNSAUS           NaN
# BUSAPPWNSAUSYY         NaN
#                     ...
# TLAACBW027NBOG    0.972114
# TLBACBW027NBOG    0.971807
# TSIFRGHT          0.968472
# UNRATE           -0.964499
# WLEMUINDXD       -0.204052
# Name: SP500, Length: 68, dtype: float64

# %%
series.query("""series_id == 'UNRATE'""")
# Out:
#    series_id               name frequency    units  seasonal_adjustment  \
# 69    UNRATE  Unemployment Rate   Monthly  Percent  Seasonally Adjusted
#
#                                           Description
# 69  The unemployment rate represents the number of...

# %%
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
m = Prophet()

features = pd.DataFrame({'ds': normed_obs.index, 'y': normed_obs['SP500'], 'unem': normed_obs['UNRATE']})
features = features.loc[features.index >= '2011-02-14']

# %%
features['unem'] = features['unem'].fillna(method='ffill')
features = features.loc[features.index >= '2011-03-01']
features
# Out:
#                    ds         y      unem
# date
# 2011-03-01 2011-03-01 -1.349348  1.637112
# 2011-03-02 2011-03-02 -1.344029  1.637112
# 2011-03-03 2011-03-03 -1.287236  1.637112
# 2011-03-04 2011-03-04 -1.311990  1.637112
# 2011-03-05 2011-03-05       NaN  1.637112
# ...               ...       ...       ...
# 2017-12-27 2017-12-27  2.119963 -1.151405
# 2017-12-28 2017-12-28  2.132365 -1.151405
# 2017-12-29 2017-12-29  2.097250 -1.151405
# 2017-12-30 2017-12-30       NaN -1.151405
# 2017-12-31 2017-12-31       NaN -1.151405
#
# [2498 rows x 3 columns]

# %%
m.add_regressor("unem", standardize=False)
train = features.iloc[:-200]
test = features.iloc[-200:]
train
# Out:
#                    ds         y      unem
# date
# 2011-03-01 2011-03-01 -1.349348  1.637112
# 2011-03-02 2011-03-02 -1.344029  1.637112
# 2011-03-03 2011-03-03 -1.287236  1.637112
# 2011-03-04 2011-03-04 -1.311990  1.637112
# 2011-03-05 2011-03-05       NaN  1.637112
# ...               ...       ...       ...
# 2017-06-10 2017-06-10       NaN -1.037588
# 2017-06-11 2017-06-11       NaN -1.037588
# 2017-06-12 2017-06-12  1.481628 -1.037588
# 2017-06-13 2017-06-13  1.509256 -1.037588
# 2017-06-14 2017-06-14  1.503130 -1.037588
#
# [2298 rows x 3 columns]

# %%
m.fit(features)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=200)
future
# Out:
#              ds
# 0    2011-03-01
# 1    2011-03-02
# 2    2011-03-03
# 3    2011-03-04
# 4    2011-03-05
# ...         ...
# 2493 2017-12-27
# 2494 2017-12-28
# 2495 2017-12-29
# 2496 2017-12-30
# 2497 2017-12-31
#
# [2498 rows x 1 columns]

# %%
# future.set_index("ds", inplace=True)
future['unem'] = features['unem']
future.reset_index(inplace=True)

# %%
future.tail()
# Out:
#              ds      unem
# 2493 2017-12-27 -1.151405
# 2494 2017-12-28 -1.151405
# 2495 2017-12-29 -1.151405
# 2496 2017-12-30 -1.151405
# 2497 2017-12-31 -1.151405

# %%
forecast = m.predict(future)

# %%
forecast.set_index("ds", inplace=True)

# %%
fig, ax = plt.subplots(figsize=(16,9))
forecast['yhat'].plot(ax=ax)
features['y'].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.59.tar.gz (25 kB)
# Requirement already satisfied: pandas>=0.24 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from yfinance) (1.2.3)
# Requirement already satisfied: numpy>=1.15 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests>=2.20 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from yfinance) (2.25.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.3-cp38-cp38-macosx_10_9_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from requests>=2.20->yfinance) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/arunavgupta/anaconda3/envs/dh21/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=480c27f097e4341a1dc7934585cfd931dd6d4a6a9b5d6ce2760fff72243dac80
#   Stored in directory: /Users/arunavgupta/Library/Caches/pip/wheels/7e/d5/f4/f628965651f61ae35c2bdc73571ce1a2026e1550a336b5ad4b
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=6245ddc1424114022fb478cf54248f918ca91e9909316b41ab95353f20a758c1
#   Stored in directory: /Users/arunavgupta/Library/Caches/pip/wheels/57/6d/a3/a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, lxml, yfinance
# Successfully installed lxml-4.6.3 multitasking-0.0.9 yfinance-0.1.59

# %%
import yfinance as yf

test_obs = pd.read_csv("data/observations_test.csv")
test_unem = normalize(test_obs.query("""series_id == 'UNRATE'""").set_index("date"))['value']

ticker = yf.Ticker("SPY")
hist = ticker.history(start="2018-01-02",  end="2020-04-01")

# %%
hist['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
test_unem.index = pd.to_datetime(test_unem.index)
test_unem
# Out:
# date
# 2018-02-01   -0.036799
# 2018-03-01   -0.084113
# 2018-04-01   -0.084113
# 2018-05-01   -0.178739
# 2018-06-01   -0.084113
# 2018-07-01   -0.178739
# 2018-08-01   -0.178739
# 2018-09-01   -0.226052
# 2018-10-01   -0.178739
# 2018-11-01   -0.226052
# 2018-12-01   -0.131426
# 2019-01-01   -0.084113
# 2019-02-01   -0.178739
# 2019-03-01   -0.178739
# 2019-04-01   -0.273366
# 2019-05-01   -0.273366
# 2019-06-01   -0.226052
# 2019-07-01   -0.226052
# 2019-08-01   -0.226052
# 2019-09-01   -0.320679
# 2019-10-01   -0.273366
# 2019-11-01   -0.320679
# 2019-12-01   -0.320679
# 2020-01-01   -0.273366
# 2020-02-01   -0.320679
# 2020-03-01    0.105141
# 2020-04-01    4.978411
# Name: value, dtype: float64

# %%
future2 = m.make_future_dataframe(periods=822)

# %%
future2.set_index("ds", inplace=True)
future2.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2020-03-28 00:00:00, 2020-03-29 00:00:00, 2020-03-30 00:00:00, 2020-03-31 00:00:00, 2020-04-01 00:00:00]

# %%
future2['unem'] = features['unem'].append(test_unem)
future2['unem'] = future2['unem'].fillna(method='bfill')
future2.tail()
# Out:
#                 unem
# ds
# 2020-03-28  4.978411
# 2020-03-29  4.978411
# 2020-03-30  4.978411
# 2020-03-31  4.978411
# 2020-04-01  4.978411

# %%
future2.reset_index(inplace=True)

# %%
future2
# Out:
#              ds      unem
# 0    2011-03-01  1.637112
# 1    2011-03-02  1.637112
# 2    2011-03-03  1.637112
# 3    2011-03-04  1.637112
# 4    2011-03-05  1.637112
# ...         ...       ...
# 3315 2020-03-28  4.978411
# 3316 2020-03-29  4.978411
# 3317 2020-03-30  4.978411
# 3318 2020-03-31  4.978411
# 3319 2020-04-01  4.978411
#
# [3320 rows x 2 columns]

# %%
forecastback = m.predict(future2)

# %%
forecastback
# Out:
#              ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0    2011-03-01 -1.168524   -1.425405   -1.181702    -1.168524    -1.168524
# 1    2011-03-02 -1.169388   -1.430947   -1.186612    -1.169388    -1.169388
# 2    2011-03-03 -1.170251   -1.431262   -1.176396    -1.170251    -1.170251
# 3    2011-03-04 -1.171115   -1.423853   -1.178110    -1.171115    -1.171115
# 4    2011-03-05 -1.171978   -1.546153   -1.304793    -1.171978    -1.171978
# ...         ...       ...         ...         ...          ...          ...
# 3315 2020-03-28  3.717147    2.277378    3.825620     2.983190     4.489076
# 3316 2020-03-29  3.719496    2.272876    3.834556     2.983984     4.492117
# 3317 2020-03-30  3.721845    2.398780    3.957169     2.984493     4.495158
# 3318 2020-03-31  3.724194    2.388987    3.961397     2.985001     4.498199
# 3319 2020-04-01  3.726542    2.397679    3.966369     2.985509     4.501240
#
#       additive_terms  additive_terms_lower  additive_terms_upper  \
# 0          -0.137344             -0.137344             -0.137344
# 1          -0.136914             -0.136914             -0.136914
# 2          -0.134360             -0.134360             -0.134360
# 3          -0.133254             -0.133254             -0.133254
# 4          -0.250907             -0.250907             -0.250907
# ...              ...                   ...                   ...
# 3315       -0.661427             -0.661427             -0.661427
# 3316       -0.662762             -0.662762             -0.662762
# 3317       -0.549655             -0.549655             -0.549655
# 3318       -0.547322             -0.547322             -0.547322
# 3319       -0.549674             -0.549674             -0.549674
#
#       extra_regressors_additive  ...    weekly  weekly_lower  weekly_upper  \
# 0                     -0.206718  ...  0.034347      0.034347      0.034347
# 1                     -0.206718  ...  0.033500      0.033500      0.033500
# 2                     -0.206718  ...  0.034847      0.034847      0.034847
# 3                     -0.206718  ...  0.034789      0.034789      0.034789
# 4                     -0.206718  ... -0.084006     -0.084006     -0.084006
# ...                         ...  ...       ...           ...           ...
# 3315                  -0.628623  ... -0.084006     -0.084006     -0.084006
# 3316                  -0.628623  ... -0.084006     -0.084006     -0.084006
# 3317                  -0.628623  ...  0.030529      0.030529      0.030529
# 3318                  -0.628623  ...  0.034347      0.034347      0.034347
# 3319                  -0.628623  ...  0.033500      0.033500      0.033500
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0     0.035027      0.035027      0.035027                   0.0
# 1     0.036304      0.036304      0.036304                   0.0
# 2     0.037511      0.037511      0.037511                   0.0
# 3     0.038674      0.038674      0.038674                   0.0
# 4     0.039817      0.039817      0.039817                   0.0
# ...        ...           ...           ...                   ...
# 3315  0.051202      0.051202      0.051202                   0.0
# 3316  0.049867      0.049867      0.049867                   0.0
# 3317  0.048439      0.048439      0.048439                   0.0
# 3318  0.046954      0.046954      0.046954                   0.0
# 3319  0.045449      0.045449      0.045449                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                            0.0                         0.0 -1.305868
# 1                            0.0                         0.0 -1.306301
# 2                            0.0                         0.0 -1.304612
# 3                            0.0                         0.0 -1.304369
# 4                            0.0                         0.0 -1.422885
# ...                          ...                         ...       ...
# 3315                         0.0                         0.0  3.055720
# 3316                         0.0                         0.0  3.056734
# 3317                         0.0                         0.0  3.172190
# 3318                         0.0                         0.0  3.176871
# 3319                         0.0                         0.0  3.176869
#
# [3320 rows x 25 columns]

# %%
full_sp500 = ticker.history(start="2011-03-01",  end="2020-04-01")

# %%
fig,ax = plt.subplots(figsize=(16, 9))
forecastback[['ds', 'yhat_lower', 'yhat', 'yhat_upper']].plot("ds", ax=ax)
normalize(full_sp500['Close']).plot(ax=ax)
# ax.set_xlim(['2020-02-01', '2020-04-01'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Adding infectious diseases

# %%
series.loc[series.name.str.contains("Disease")]
# Out:
#              series_id                                               name  \
# 39  INFECTDISEMVTRACKD  Equity Market Volatility: Infectious Disease T...
#
#        frequency  units      seasonal_adjustment  \
# 39  Daily, 7-Day  Index  Not Seasonally Adjusted
#
#                                           Description
# 39  Assessing the economic impact of the COVID-19 ...

# %%
normed_obs['INFECTDISEMVTRACKD'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
corona = test_obs.query("""series_id == 'INFECTDISEMVTRACKD'""")
corona.set_index(pd.to_datetime(corona.date), inplace=True)
corona['value'].plot()
corona
# Out:
#                      series_id                         date  value
# date
# 2018-01-02  INFECTDISEMVTRACKD  2018-01-02 00:00:00.0000000   0.00
# 2018-01-03  INFECTDISEMVTRACKD  2018-01-03 00:00:00.0000000   0.73
# 2018-01-04  INFECTDISEMVTRACKD  2018-01-04 00:00:00.0000000   0.00
# 2018-01-05  INFECTDISEMVTRACKD  2018-01-05 00:00:00.0000000   1.22
# 2018-01-06  INFECTDISEMVTRACKD  2018-01-06 00:00:00.0000000   0.61
# ...                        ...                          ...    ...
# 2020-06-10  INFECTDISEMVTRACKD  2020-06-10 00:00:00.0000000  18.82
# 2020-06-11  INFECTDISEMVTRACKD  2020-06-11 00:00:00.0000000  24.17
# 2020-06-12  INFECTDISEMVTRACKD  2020-06-12 00:00:00.0000000  24.89
# 2020-06-13  INFECTDISEMVTRACKD  2020-06-13 00:00:00.0000000  25.01
# 2020-06-14  INFECTDISEMVTRACKD  2020-06-14 00:00:00.0000000  42.72
#
# [895 rows x 3 columns]

# %%
m2 = Prophet()

# %%
m2.add_regressor("unem", standardize=False)
m2.add_regressor("infect", standardize=False)

features['infect'] = normed_obs['INFECTDISEMVTRACKD']
features
# Out:
#                    ds         y      unem    infect
# date
# 2011-03-01 2011-03-01 -1.349348  1.637112 -0.494192
# 2011-03-02 2011-03-02 -1.344029  1.637112 -0.494192
# 2011-03-03 2011-03-03 -1.287236  1.637112 -0.494192
# 2011-03-04 2011-03-04 -1.311990  1.637112 -0.494192
# 2011-03-05 2011-03-05       NaN  1.637112 -0.001499
# ...               ...       ...       ...       ...
# 2017-12-27 2017-12-27  2.119963 -1.151405 -0.120110
# 2017-12-28 2017-12-28  2.132365 -1.151405 -0.494192
# 2017-12-29 2017-12-29  2.097250 -1.151405 -0.083614
# 2017-12-30 2017-12-30       NaN -1.151405 -0.494192
# 2017-12-31 2017-12-31       NaN -1.151405  1.111622
#
# [2498 rows x 4 columns]

# %%
m2.fit(features)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future3 = future2.copy(deep=True)
future3.set_index("ds", inplace=True)
raw_infect = observations.query("""series_id == 'INFECTDISEMVTRACKD'""")
raw_infect.set_index(pd.to_datetime(raw_infect.date), inplace=True)
raw_infect
# Out:
#                      series_id       date  value
# date
# 2000-01-02  INFECTDISEMVTRACKD 2000-01-02   2.62
# 2000-01-03  INFECTDISEMVTRACKD 2000-01-03   0.00
# 2000-01-04  INFECTDISEMVTRACKD 2000-01-04   0.99
# 2000-01-05  INFECTDISEMVTRACKD 2000-01-05   0.00
# 2000-01-06  INFECTDISEMVTRACKD 2000-01-06   0.00
# ...                        ...        ...    ...
# 2017-12-27  INFECTDISEMVTRACKD 2017-12-27   0.41
# 2017-12-28  INFECTDISEMVTRACKD 2017-12-28   0.00
# 2017-12-29  INFECTDISEMVTRACKD 2017-12-29   0.45
# 2017-12-30  INFECTDISEMVTRACKD 2017-12-30   0.00
# 2017-12-31  INFECTDISEMVTRACKD 2017-12-31   1.76
#
# [6574 rows x 3 columns]

# %%
future3['infect'] = raw_infect['value'].append(corona['value'])
future3.reset_index(inplace=True)
future3['infect'].fillna(method='ffill', inplace=True)
future3.head()
# Out:
#           ds      unem  infect
# 0 2011-03-01  1.637112    0.00
# 1 2011-03-02  1.637112    0.00
# 2 2011-03-03  1.637112    0.00
# 3 2011-03-04  1.637112    0.00
# 4 2011-03-05  1.637112    0.54

# %%
future3.query("infect != infect")
# Out:
# Empty DataFrame
# Columns: [ds, unem, infect]
# Index: []

# %%
forecast3 = m2.predict(future3)
forecast3
# Out:
#              ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0    2011-03-01 -1.191171   -1.449006   -1.189239    -1.191171    -1.191171
# 1    2011-03-02 -1.191910   -1.449367   -1.204126    -1.191910    -1.191910
# 2    2011-03-03 -1.192648   -1.445027   -1.195479    -1.192648    -1.192648
# 3    2011-03-04 -1.193387   -1.443107   -1.201997    -1.193387    -1.193387
# 4    2011-03-05 -1.194126   -1.559346   -1.307148    -1.194126    -1.194126
# ...         ...       ...         ...         ...          ...          ...
# 3315 2020-03-28  3.717128    1.418283    3.088358     2.888724     4.521629
# 3316 2020-03-29  3.719472    0.764941    2.426089     2.890175     4.526176
# 3317 2020-03-30  3.721816    1.839918    3.472513     2.891678     4.530724
# 3318 2020-03-31  3.724160    1.511136    3.163082     2.893031     4.535271
# 3319 2020-04-01  3.726504    1.697065    3.380312     2.894374     4.539819
#
#       additive_terms  additive_terms_lower  additive_terms_upper  \
# 0          -0.130713             -0.130713             -0.130713
# 1          -0.131157             -0.131157             -0.131157
# 2          -0.130702             -0.130702             -0.130702
# 3          -0.128971             -0.128971             -0.128971
# 4          -0.237944             -0.237944             -0.237944
# ...              ...                   ...                   ...
# 3315       -1.454640             -1.454640             -1.454640
# 3316       -2.118024             -2.118024             -2.118024
# 3317       -1.039341             -1.039341             -1.039341
# 3318       -1.353874             -1.353874             -1.353874
# 3319       -1.175240             -1.175240             -1.175240
#
#       extra_regressors_additive  ...    weekly  weekly_lower  weekly_upper  \
# 0                     -0.200262  ...  0.031101      0.031101      0.031101
# 1                     -0.200262  ...  0.029280      0.029280      0.029280
# 2                     -0.200262  ...  0.028444      0.028444      0.028444
# 3                     -0.200262  ...  0.028945      0.028945      0.028945
# 4                     -0.209242  ... -0.072236     -0.072236     -0.072236
# ...                         ...  ...       ...           ...           ...
# 3315                  -1.435335  ... -0.072236     -0.072236     -0.072236
# 3316                  -2.097373  ... -0.072236     -0.072236     -0.072236
# 3317                  -1.116206  ...  0.026701      0.026701      0.026701
# 3318                  -1.433672  ...  0.031101      0.031101      0.031101
# 3319                  -1.251740  ...  0.029280      0.029280      0.029280
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0     0.038448      0.038448      0.038448                   0.0
# 1     0.039825      0.039825      0.039825                   0.0
# 2     0.041116      0.041116      0.041116                   0.0
# 3     0.042345      0.042345      0.042345                   0.0
# 4     0.043535      0.043535      0.043535                   0.0
# ...        ...           ...           ...                   ...
# 3315  0.052931      0.052931      0.052931                   0.0
# 3316  0.051586      0.051586      0.051586                   0.0
# 3317  0.050163      0.050163      0.050163                   0.0
# 3318  0.048696      0.048696      0.048696                   0.0
# 3319  0.047219      0.047219      0.047219                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                            0.0                         0.0 -1.321884
# 1                            0.0                         0.0 -1.323067
# 2                            0.0                         0.0 -1.323350
# 3                            0.0                         0.0 -1.322359
# 4                            0.0                         0.0 -1.432071
# ...                          ...                         ...       ...
# 3315                         0.0                         0.0  2.262487
# 3316                         0.0                         0.0  1.601448
# 3317                         0.0                         0.0  2.682475
# 3318                         0.0                         0.0  2.370285
# 3319                         0.0                         0.0  2.551263
#
# [3320 rows x 28 columns]

# %%
fig,ax = plt.subplots(figsize=(16, 9))
forecast3[['ds', 'yhat_lower', 'yhat', 'yhat_upper']].plot("ds", ax=ax)
normalize(full_sp500['Close']).plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
series.series_id.unique()
# Out:
# array(['AAA10Y', 'ASEANTOT', 'BAA10Y', 'BUSAPPWNSAUS', 'BUSAPPWNSAUSYY',
#        'CBUSAPPWNSAUS', 'CBUSAPPWNSAUSYY', 'CUUR0000SA0R', 'DEXCHUS',
#        'DEXJPUS', 'DEXUSEU', 'DEXUSUK', 'DFII10', 'DFII20', 'DFII30',
#        'DFII5', 'DFII7', 'DLTIIT', 'DPCREDIT', 'DPRIME', 'EECTOT', 'EFFR',
#        'EFFRVOL', 'FRGSHPUSM649NCIS', 'GVIPT50002S', 'GVIPT50030S',
#        'GVIPT51000S', 'GVIPT51100S', 'GVIPT51110S', 'GVIPT51120S',
#        'GVIPT51200S', 'GVIPT52000S', 'GVIPT52100S', 'GVIPT521A3S',
#        'GVIPT52300S', 'GVIPT54000S', 'GVIPT54100S', 'GVIPT54200S',
#        'GVIPT54220S', 'INFECTDISEMVTRACKD', 'IOER', 'IORR',
#        'MEDCPIM158SFRBCLE', 'MORTGAGE15US', 'MORTGAGE30US', 'OBFR',
#        'OBFRVOL', 'PCUADLVWRADLVWR', 'PCUAINFOAINFO', 'PCUAMUMAMUM',
#        'PCUARETTRARETTR', 'PCUASHCASHC', 'PCUASTDSVASTDSV',
#        'PCUATRADEATRADE', 'PCUATRANSATRANS', 'PCUATRNWRATRNWR',
#        'PCUATTDSVATTDSV', 'PCUAWHLTRAWHLTR', 'PCUOMFGOMFG', 'PCUOMINOMIN',
#        'SFTPAGRM158SFRBSF', 'SOFR', 'SOFRVOL', 'SP500', 'T10YIE',
#        'TEDRATE', 'TLAACBW027NBOG', 'TLBACBW027NBOG', 'TSIFRGHT',
#        'UNRATE', 'WLEMUINDXD'], dtype=object)
